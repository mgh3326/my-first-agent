# %%
import openai
from dotenv import load_dotenv
# .env 파일에서 환경 변수를 로드합니다.
load_dotenv()
client = openai.OpenAI()
messages = []

# %%
def call_ai():
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=messages,
    )
    message = response.choices[0].message.content
    messages.append({"role": "assistant", "content": message})
    print(f"AI: {message}")

# %%
while True:
    message = input("Send a message to the LLM...")
    if message == "quit" or message == "q":
        break
    else:
        messages.append({"role": "user", "content": message})
        print(f"User: {message}")
        call_ai()
# Out:
# User: My name is Kwanghyun
# AI: Nice to meet you, Kwanghyun! How can I assist you today?
# User: What is my name?
# AI: Your name is Kwanghyun. How can I assist you further?
# User: I'm from korea
# AI: That's great to hear, Kwanghyun! Korea has a rich culture and history. Is there anything specific you'd like to talk about, whether it's about Korea or something else?
